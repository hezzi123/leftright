# %%
#import some libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics import f1_score
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
# Reading the datasets of the training
spont1 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Evyatar Cohen\Evyatar636771052727603804Spontan.csv")
sync1 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Evyatar Cohen\Evyatar636771053639929594Sync.csv")
alone1 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Evyatar Cohen\Evyatar636771054555711409Alone.csv")
spont1 = spont1.iloc[701:]
sync1 = sync1.iloc[701:]
alone1 = alone1.iloc[701:]

# %%
spont2 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Nofar Social_Nuero\Nofar636759795182793299Spontan.csv")
alone2 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Nofar Social_Nuero\Nofar636759796290435160Alone.csv")
sync2 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Nofar Social_Nuero\Nofar636759797397919664Sync.csv")
spont2 = spont2.iloc[701:]
sync2 = sync2.iloc[701:]
alone2 = alone2.iloc[701:]

# %%
spont3 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Oriya Social_Nuero\Oriya636759804404113837Spontan.csv")
alone3 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Oriya Social_Nuero\Oriya636759805268396661Alone.csv")
sync3 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Oriya Social_Nuero\Oriya636759806131350399Sync.csv")
spont3 = spont3.iloc[701:]
sync3 = sync3.iloc[701:]
alone3 = alone3.iloc[701:]

# %%
sync4 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Orya Kalmanovitz\OryaB636771084494502229Sync.csv")
spont4 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Orya Kalmanovitz\OryaB636771083605535985Spontan.csv")
alone4 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Orya Kalmanovitz\OryaB636771082736601528Alone.csv")
spont4 = spont4.iloc[701:]
sync4 = sync4.iloc[701:]
alone4 = alone4.iloc[701:]

# %%
sync5 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Revital Marbel\Revital636770957894370062Sync.csv")
spont5 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Revital Marbel\Revital636770957038873193Spontan.csv")
alone5 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Revital Marbel\Revital636770955999435879Alone.csv")
spont5 = spont5.iloc[701:]
sync5 = sync5.iloc[701:]
alone5 = alone5.iloc[701:]

# %%
alone6 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Shahar Terner\Sachar636771047408504303Alone.csv")
sync6 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Shahar Terner\Sachar636771046527112972Sync.csv")
spont6 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Shahar Terner\Sachar636771045591258071Spontan.csv")
spont6 = spont6.iloc[701:]
sync6 = sync6.iloc[701:]
alone6 = alone6.iloc[701:]

# %%
spont7 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Shelly Social_Nuero\Shelly636759787508979097Spontan.csv")
alone7 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Shelly Social_Nuero\Shelly636759788383205274Alone.csv")
sync7 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Shelly Social_Nuero\Shelly636759789526313406Sync.csv")
spont7 = spont7.iloc[701:]
sync7 = sync7.iloc[701:]
alone7 = alone7.iloc[701:]

# %%
spont8 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Yael Hagai\Yael636771059544754823Spontan.csv")
sync8 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Yael Hagai\Yael636771060699529085Sync.csv")
alone8 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Yael Hagai\Yael636771061659067649Alone.csv")
spont8 = spont8.iloc[701:]
sync8 = sync8.iloc[701:]
alone8 = alone8.iloc[701:]

# %%
spont9 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Yoel Raz\Yoel636760921663075813Spontan.csv")
alone9 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Yoel Raz\Yoel636760922573364655Alone.csv")
sync9 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Training\Yoel Raz\Yoel636760923490742912Sync.csv")
spont9 = spont9.iloc[701:]
sync9 = sync9.iloc[701:]
alone9 = alone9.iloc[701:]

# %%
# making 1 data for each type
# Clean the data
frame1 = [spont1 ,spont2 , spont3 , spont4 ,spont5 , spont6 , spont7 , spont8 , spont9]
spont_end = pd.concat(frame1)
spont_end['Type'] = 'spontan'
spont_end = spont_end[spont_end[' # hands'] == 2]

# %%
right_hand = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\HandRight.csv")
right_hand = right_hand.iloc[701:]

# %%
frame2 = [alone1, right_hand ,alone2, right_hand , alone3, right_hand , alone4,right_hand  ,alone5, right_hand , alone6, right_hand , alone7, right_hand , alone8, right_hand , alone9 , right_hand]
alone_end = pd.concat(frame2)
alone_end['Type'] = 'alone'
alone_end = alone_end[alone_end[' # hands'] == 1]

# %%
frame3 = [sync1 ,sync2 , sync3 , sync4 ,sync5 , sync6 , sync7 , sync8 , sync9]
sync_end = pd.concat(frame3)
sync_end['Type'] = 'sync'
sync_end = sync_end[sync_end[' # hands'] == 2]

# %%
# Conact the all 3 datas
frame4 = [sync_end , alone_end , spont_end]
data = pd.concat(frame4)

# %%
# checking the count of every type
data.groupby('Type').count()
# Out:
#           Time   Frame ID   Hand Type   # hands   Position X   Position Y  \
# Type
# alone    68226      68226       68226     68226        68226        68226
# spontan  69123      69123       69123     69123        69123        69123
# sync     68969      68969       68969     68969        68969        68969
#
#           Position Z   Velocity X   Velocity Y   Velocity Z  ...    Yaw  \
# Type                                                         ...
# alone          68226        68226        68226        68226  ...  68226
# spontan        69123        69123        69123        69123  ...  69123
# sync           68969        68969        68969        68969  ...  68969
#
#           Wrist Pos X   Wrist Pos Y   Wrist Pos Z   Elbow pos X   Elbow Pos Y  \
# Type
# alone           64770         64770         64770         64770         64770
# spontan         69123         69123         69123         69123         69123
# ...

# %%
# Drop the clean column
data = data.drop([' # hands' ],axis=1)

# %%
# Reading the datasets of the test
spont1 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Validation\Itiel Lab\Itiel636770940701219076Spontan.csv")
sync1 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Validation\Itiel Lab\Itiel636770941638547912Sync.csv")
alone1 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Validation\Itiel Lab\Itiel636770942529041679Alone.csv")
spont1 = spont1.iloc[701:]
sync1 = sync1.iloc[701:]
alone1 = alone1.iloc[701:]

# %%
spont2 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Validation\Mor SHerman\Mor636771064635567065Spontan.csv")
alone2 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Validation\Mor SHerman\Mor636771066407626524Alone.csv")
sync2 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Validation\Mor SHerman\Mor636771065531910215Sync.csv")
spont2 = spont2.iloc[701:]
sync2 = sync2.iloc[701:]
alone2 = alone2.iloc[701:]

# %%
spont3 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Validation\Oded Medina\Oded636754670490266956Spontan.csv")
alone3 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Validation\Oded Medina\Oded636754669540564461Alone.csv")
sync3 = pd.read_csv(r"D:\Ariel\Desktop\Unity Data\Validation\Oded Medina\Oded636754671560850581Sync.csv")
spont3 = spont3.iloc[701:]
sync3 = sync3.iloc[701:]
alone3 = alone3.iloc[701:]

# %%
frame1 = [spont1 ,spont2 , spont3]
spont_end = pd.concat(frame1)
spont_end['Type'] = 'spontan'
spont_end = spont_end[spont_end[' # hands'] == 2]

# %%
frame2 = [alone1, right_hand ,alone2,right_hand , alone3 , right_hand]
alone_end = pd.concat(frame2)
alone_end['Type'] = 'alone'
alone_end = alone_end[alone_end[' # hands'] == 1]

# %%
frame3 = [sync1 ,sync2 , sync3 ]
sync_end = pd.concat(frame3)
sync_end['Type'] = 'sync'
sync_end = sync_end[sync_end[' # hands'] == 2]

# %%
# Conact the all 3 datas
frame4 = [sync_end , alone_end , spont_end]
test = pd.concat(frame4)

# %%
# checking the count of every type
test.groupby('Type').count()
# Out:
#           Time   Frame ID   Hand Type   # hands   Position X   Position Y  \
# Type
# alone    21100      21100       21100     21100        21100        21100
# spontan  20288      20288       20288     20288        20288        20288
# sync     19929      19929       19929     19929        19929        19929
#
#           Position Z   Velocity X   Velocity Y   Velocity Z  ...    Yaw  \
# Type                                                         ...
# alone          21100        21100        21100        21100  ...  21100
# spontan        20288        20288        20288        20288  ...  20288
# sync           19929        19929        19929        19929  ...  19929
#
#           Wrist Pos X   Wrist Pos Y   Wrist Pos Z   Elbow pos X   Elbow Pos Y  \
# Type
# alone           19948         19948         19948         19948         19948
# spontan         20288         20288         20288         20288         20288
# ...

# %%
# Drop the clean column
test = test.drop([' # hands' , ],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
data[' Hand Type'] = le.fit_transform(data[' Hand Type'])
dict(zip(le.classes_, le.transform(le.classes_)))
# Out:
# {'left': 0, 'right': 1}

# %%
le = LabelEncoder()
test[' Hand Type'] = le.fit_transform(test[' Hand Type'])
dict(zip(le.classes_, le.transform(le.classes_)))
# Out:
# {'left': 0, 'right': 1}

# %%
# clean the both datas
data = data.dropna()
test = test.dropna()

# %%
# visualation
corr = data.corr()
plt.figure(figsize = (30,10))
sns.heatmap(data=corr, square=True , annot=True, cbar=True)

# %%
#histograma
data.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000148809C5FD0>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(1,3,1)
data.groupby(['Type'])[' Velocity Z', ' Velocity Z'].mean().plot(kind='bar', title='Velocity z', ax=ax)
ax2 = fig.add_subplot(1,3,2)
data.groupby(['Type'])[' Velocity Y', ' Velocity Y'].mean().plot(kind='bar', title= 'Velocity y',ax=ax2)
ax3 = fig.add_subplot(1,3,3)
data.groupby(['Type'])[' Velocity X', ' Velocity X'].mean().plot(kind='bar', title= 'Velocity x',ax=ax3)

# %%
b = sns.boxplot(x= ' Roll', y = 'Type', data = data)
b.axes.set_title("Type is effected by Roll?" , fontsize=25, color = 'brown')
b.set_xlabel("Roll",fontsize=15 , color = 'red')
b.set_ylabel("Type",fontsize=15 , color = 'red')
b.tick_params(labelsize=25 , color = 'red')

# %%
b = sns.boxplot(x= ' Yaw', y = 'Type', data = data)
b.axes.set_title("type is effected by yaw?" , fontsize=25, color = 'brown')
b.set_xlabel("Yaw",fontsize=15 , color = 'red')
b.set_ylabel("Type",fontsize=15 , color = 'red')
b.tick_params(labelsize=25 , color = 'red')

# %%
# Wrist with the same variable are connected to position with the same variable
sns.kdeplot(data[' Position Y'], shade=True , color='g' )
sns.kdeplot(data[' Wrist Pos Y'], shade=True , color='grey' )

# %%
sns.kdeplot(data[' Position X'], shade= True , color='b')
sns.kdeplot(data[' Wrist Pos X'], shade= True , color='orange')

# %%
sns.kdeplot(data[' Wrist Pos Z'] ,shade=True , color='yellow' )
sns.kdeplot(data[' Position Z'] ,shade=True , color='r' )

# %%
# checking they have the same amount of hands
b = sns.countplot(x = ' Hand Type',hue = 'Type' ,data = data)
b.axes.set_title("how many hands" , fontsize=25, color = 'brown')
b.set_xlabel("right or left",fontsize=20 , color = 'red')
b.set_ylabel("Hands",fontsize=20 , color = 'red')
b.tick_params(labelsize= 15 , color = 'red')

# %%
#Create my test and train
from sklearn.model_selection import train_test_split, cross_val_score
X = data.drop(['Type','Time' ,' Roll' , ' Yaw'], axis = 1)
y = data['Type']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 62)

# %%
#Logistic Regression

# import the class
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# instantiate the model
logreg = LogisticRegression()

# fit the model with data
logreg.fit(X_train , y_train)

# store the predicted response values
y_pred = logreg.predict(X_test)

# compute classification accuracy for the logistic regression model
accuracy = accuracy_score(y_test, y_pred)
print('%',(accuracy *100))
# Out:
# c:\python\python36\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\python\python36\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# % 62.645455224437974

# %%
# nauve bayes
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train,y_train)
gnb.score(X_test,y_test)
# Out:
# 0.6434386436627082

# %%
# PCA
d_range = list(range(1, 17))
d_scores = []
for d in d_range:
    pca = PCA(n_components=d)
    pc = pca.fit_transform(X_train)
    pc_t = pca.fit_transform(X_test)
    rfc = RandomForestClassifier(n_estimators=100, max_depth=20,random_state=1)
    rfc.fit(pc, y_train)
    scores = rfc.score(pc_t,y_test)
    d_scores.append(scores.mean())
plt.plot(d_range, d_scores)
plt.xlabel('Value of n PCA components')
plt.ylabel('Cross-Validated Accuracy')
# Out:
# Text(0, 0.5, 'Cross-Validated Accuracy')

# %%
# as we can see when the value of the PCA is 13 we will get the highest accuary and it is : 0.79

# %%
#Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=200) #create the model, The number of trees in the forest.

#Enter the data training to the model, build a forest of trees from the training set.
rfc.fit(X_train, y_train)

#Predict class for X.
pred_rfc = rfc.predict(X_test)
print(pred_rfc)

#Accuracy percentages
accuracy =  rfc.score(X_test, y_test)

print('% Random forest classifier accuracy:', accuracy*100)
# Out:
# ['alone' 'alone' 'alone' ... 'spontan' 'sync' 'spontan']
# % Random forest classifier accuracy: 99.90290537007992

# %%
# knn
from sklearn.neighbors import KNeighborsClassifier

#create the model
knn = KNeighborsClassifier(n_neighbors=1)

#Enter the data training to the mode
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
print(f1_score(y_pred=knn.predict(X_test),y_true=y_test,average='weighted'))
# Out:
# 0.9977443675917008

# %%
# adaboost
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
clf = AdaBoostClassifier(RandomForestClassifier(n_estimators=5, max_depth=5,random_state=1,n_jobs=-1), n_estimators=100, random_state=0)
clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.9848980506385839
